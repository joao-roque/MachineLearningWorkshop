# %%
import sklearn
import numpy as np
import pandas as pd
import csv
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Titanic Analysis
# Load files
test = pd.read_csv('../data/test.csv')
train = pd.read_csv('../data/train.csv', sep = ',')

list(train)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
# Decide which variables to use

# Plano:
# Fazer testes de correlação entre todas as variáveis e 'Survived' para ver quais seriam melhores para classificação 

age = train.Age[~np.isnan(train.Age)]
sns.set(color_codes=True)
sns.distplot(age)
